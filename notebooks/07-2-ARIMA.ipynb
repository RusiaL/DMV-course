# %%
# Installation of the library can take some time. Please, be patient and wait
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading cython-3.2.4-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (2.1.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (1.15.3)
# Collecting statsmodels>=0.14.5 (from pmdarima)
#   Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: urllib3 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (2.3.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (72.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\vira.liubchenko\appdata\local\anaconda3\lib\site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.1)
# Downloading pmdarima-2.1.1-cp313-cp313-win_amd64.whl (711 kB)
#    ---------------------------------------- 0.0/711.9 kB ? eta -:--:--
#    ---------------------------------------- 711.9/711.9 kB 9.2 MB/s eta 0:00:00
# Downloading cython-3.2.4-cp313-cp313-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------------------- ------------- 1.8/2.8 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 9.5 MB/s eta 0:00:00
# Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.5 MB 13.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.5 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: Cython, statsmodels, pmdarima
#
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#    ---------------------------------------- 0/3 [Cython]
#   Attempting uninstall: statsmodels
#    ---------------------------------------- 0/3 [Cython]
#    ------------- -------------------------- 1/3 [statsmodels]
#     Found existing installation: statsmodels 0.14.4
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#     Uninstalling statsmodels-0.14.4:
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#       Successfully uninstalled statsmodels-0.14.4
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    ---------------------------------------- 3/3 [pmdarima]
#
# Successfully installed Cython-3.2.4 pmdarima-2.1.1 statsmodels-0.14.6

# %%
import pandas as pd                   # for reading & storing data, pre-processing
import matplotlib.pylab as plt        # for visualization
from pmdarima.arima import auto_arima # for ARIMA model discovering

# %matplotlib inline

# %%
df = pd.read_csv("data/07-covid-19.csv")
df.head()
# Out:
#        country country_code continent  population indicator  weekly_count  \
# 0  Afghanistan          AFG      Asia    38928341     cases           0.0
# 1  Afghanistan          AFG      Asia    38928341     cases           0.0
# 2  Afghanistan          AFG      Asia    38928341     cases           0.0
# 3  Afghanistan          AFG      Asia    38928341     cases           0.0
# 4  Afghanistan          AFG      Asia    38928341     cases           0.0
#
#   year_week  rate_14_day  cumulative_count  \
# 0   2020-01          NaN               0.0
# 1   2020-02          0.0               0.0
# 2   2020-03          0.0               0.0
# 3   2020-04          0.0               0.0
# 4   2020-05          0.0               0.0
#
#                                 source  note
# 0  Epidemic intelligence national data   NaN
# 1  Epidemic intelligence national data   NaN
# 2  Epidemic intelligence national data   NaN
# 3  Epidemic intelligence national data   NaN
# 4  Epidemic intelligence national data   NaN

# %%
# Read the Germany's records only
DEU_df = df[df['country_code'] == 'DEU'][['indicator', 'year_week', 'weekly_count']]

# Get the cases records
DEU_cases = DEU_df[DEU_df['indicator'] == 'cases'][['year_week', 'weekly_count']]

DEU_cases = DEU_cases.set_index(['year_week'])

# %%
# The auto_arima function seeks to identify the most optimal parameters for an ARIMA model, 
# and returns a fitted ARIMA model

model_autoARIMA = auto_arima(DEU_cases, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=3123.890, Time=0.06 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=3110.167, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=3105.478, Time=0.03 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=3121.920, Time=0.01 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=3106.650, Time=0.04 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=3106.880, Time=0.06 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=3086.351, Time=0.15 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=3070.717, Time=0.18 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=3071.330, Time=0.29 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=3074.020, Time=0.12 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=3074.519, Time=0.09 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=3071.882, Time=0.09 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=3070.926, Time=0.22 sec
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#
# Best model:  ARIMA(2,2,2)(0,0,0)[0] intercept
# Total fit time: 1.879 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  128
# Model:               SARIMAX(2, 2, 2)   Log Likelihood               -1529.358
# Date:                Sat, 28 Mar 2026   AIC                           3070.717
# Time:                        10:46:41   BIC                           3087.735
# Sample:                             0   HQIC                          3077.631
#                                 - 128
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -164.1061    309.366     -0.530      0.596    -770.453     442.241
# ar.L1          1.0703      0.087     12.314      0.000       0.900       1.241
# ar.L2         -0.5295      0.063     -8.425      0.000      -0.653      -0.406
# ma.L1         -0.8999      0.156     -5.783      0.000      -1.205      -0.595
# ma.L2         -0.0692      0.167     -0.415      0.678      -0.396       0.258
# sigma2      2.181e+09      0.000   1.44e+13      0.000    2.18e+09    2.18e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               780.14
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             204.58   Skew:                            -0.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.21e+29. Standard errors may be unstable.

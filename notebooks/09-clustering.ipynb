# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler #, RobustScaler
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.neighbors import LocalOutlierFactor

from sklearn.decomposition import PCA

# %%
df = pd.read_csv("data/09_spotify_5000_songs.csv")
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#   name                                                                                                                                                                               \
# 0  Se Eu Quiser Falar Com Deus                   ...
# 1  Saudade De Bahia                              ...
# 2  Canta Canta, Minha Gente                      ...
# 3  Mulher Eu Sei                                 ...
# 4  Rosa Morena                                   ...
#
#    artist                                            danceability   energy     \
# 0  Gilberto Gil                                              0.658     0.2590
# 1  Antônio Carlos Jobim                                      0.742     0.3990
# 2  Martinho Da Vila                                          0.851     0.7300
# 3  Chico César                                               0.705     0.0502
# 4  Kurt Elling                                               0.651     0.1190
#
#    key   loudness   mode   speechiness   acousticness   instrumentalness   \
# 0    11    -13.141      0        0.0705          0.694           0.000059
# 1     2    -12.646      1        0.0346          0.217           0.000002
# 2     2    -11.048      1        0.3470          0.453           0.000063
# 3     4    -18.115      1        0.0471          0.879           0.000041
# 4     6    -19.807      1        0.0380          0.916           0.000343
#
#    liveness   valence   tempo     type   duration_ms   time_signature   \
# 0      0.975     0.306   110.376               256213                4
# 1      0.107     0.693   125.039               191867                4
# 2      0.124     0.905    93.698               152267                4
# 3      0.386     0.524   106.802               186227                4
# 4      0.104     0.402   120.941               273680                4
#
#    id                                                                    html
# 0  1n7JnwviZ7zf0LR1tcGFq7   https://open.spotify.com/track/1n7JnwviZ7zf0LR...
# 1  5QGM1U0eCYrQuwSJwTm5Zq   https://open.spotify.com/track/5QGM1U0eCYrQuwS...
# 2  0NLIFSZxPzQhCwnkn5PJYs   https://open.spotify.com/track/0NLIFSZxPzQhCwn...
# 3  3mXqOdlLE1k67WsAxryPFs   https://open.spotify.com/track/3mXqOdlLE1k67Ws...
# 4  7bSzjzjTkWT2CkIPPdp0eA   https://open.spotify.com/track/7bSzjzjTkWT2CkI...

# %%
features = ['danceability ', 'energy   ', 'speechiness ', 'acousticness ', 
            'instrumentalness ', 'liveness ', 'valence ', 'tempo   ']
X = df[features]

scaler = StandardScaler() # RobustScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## How Many Clusters?

# %%
wcss = []

cluster_range = range(1, 31)  # Try k from 1 to 30

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)  # Sum of squared distances to cluster centers

plt.figure(figsize=(5,3))
plt.plot(cluster_range, wcss, marker='o')
plt.title('Elbow Method: WCSS vs Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS (Inertia)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# %%
silhouette_scores = []
cluster_range = range(2, 30)  # Silhouette score requires at least 2 clusters

for k in cluster_range:
    km = KMeans(n_clusters=k, random_state = 42)
    labels = km.fit_predict(X_scaled)  # Use pca or scaled data, as pca does not change the result, we'll stick with scaled for now
    
    score = silhouette_score(X_scaled, labels)
    silhouette_scores.append(score)

plt.figure(figsize=(5,3))
plt.plot(cluster_range, silhouette_scores, marker='o')
plt.title('KMeans Clustering Silhouette Scores')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# %%
def find_best_k(X_scaled, k_min=2, k_max=15):
    best_k = None
    best_score = -1
    scores = {}
    for k in range(k_min, k_max+1):
        km = KMeans(n_clusters=k, random_state=42)
        labels = km.fit_predict(X_scaled)
        score = silhouette_score(X_scaled, labels)
        scores[k] = score
        if score > best_score:
            best_k = k
            best_score = score
    return best_k, best_score, scores

best_k, best_score, all_scores = find_best_k(X_scaled)
print("Best k:", best_k, "with silhouette score:", best_score)
# Out:
# Best k: 2 with silhouette score: 0.28261462405065463

# %% [markdown]
# ## K-Means clustering

# %%
kmeans = KMeans(n_clusters=best_k, random_state=42)
df['Cluster_KMeans'] = kmeans.fit_predict(X_scaled)

print("KMeans Silhouette Score:", silhouette_score(X_scaled, df['Cluster_KMeans']))
# Out:
# KMeans Silhouette Score: 0.28261462405065463

# %%
from mpl_toolkits.mplot3d import Axes3D

# Step 1: Apply PCA with 3 components
pca_3d = PCA(n_components=3)
X_pca_3d = pca_3d.fit_transform(X_scaled)

# Step 2: Plot clusters in 3D 
fig = plt.figure(figsize=(18, 6))

ax1 = fig.add_subplot(projection='3d')
scatter1 = ax1.scatter(X_pca_3d[:, 0], X_pca_3d[:, 1], X_pca_3d[:, 2], c=df['Cluster_KMeans'], cmap='tab10', s=10)
ax1.set_title('KMeans Clusters')
ax1.set_xlabel('PCA1')
ax1.set_ylabel('PCA2')
ax1.set_zlabel('PCA3')
fig.colorbar(scatter1, ax=ax1, shrink=0.5)

plt.show()

# %%
# Get cluster counts
kmeans_counts = df['Cluster_KMeans'].value_counts().sort_index()

fig, axes = plt.subplots(figsize=(5, 5))

axes.bar(kmeans_counts.index.astype(str), kmeans_counts.values)
axes.set_title('KMeans Cluster Counts')
axes.set_xlabel('Cluster Label')
axes.set_ylabel('Number of Samples')

plt.show()

# %% [markdown]
# # Agglomerative Clustering

# %%
agglo = AgglomerativeClustering(n_clusters=best_k)
df['Cluster_Agglomerative'] = agglo.fit_predict(X_scaled)

print("Agglomerative Silhouette Score:", silhouette_score(X_scaled, df['Cluster_Agglomerative']))
# Out:
# Agglomerative Silhouette Score: 0.24876009308065553

# %%
X_pca_3d = pca_3d.fit_transform(X_scaled)

fig = plt.figure(figsize=(18, 6))

ax3 = fig.add_subplot(projection='3d')
scatter3 = ax3.scatter(X_pca_3d[:, 0], X_pca_3d[:, 1], X_pca_3d[:, 2], c=df['Cluster_Agglomerative'], cmap='tab10', s=10)
ax3.set_title('Agglomerative Clusters')
ax3.set_xlabel('PCA1')
ax3.set_ylabel('PCA2')
ax3.set_zlabel('PCA3')
fig.colorbar(scatter3, ax=ax3, shrink=0.5)

plt.show()

# %%
# Get cluster counts
agglo_counts = df['Cluster_Agglomerative'].value_counts().sort_index()

fig, axes = plt.subplots(figsize=(5, 5))

axes.bar(agglo_counts.index.astype(str), agglo_counts.values)
axes.set_title('Agglomerative Cluster Counts')
axes.set_xlabel('Cluster Label')
axes.set_ylabel('Number of Samples')

plt.show()

# %%
import scipy.cluster.hierarchy as sch

dendrogram = sch.dendrogram(sch.linkage(X_scaled, method='ward'))

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN(eps=1.0, min_samples=5)
df['Cluster_DBSCAN'] = dbscan.fit_predict(X_scaled)

dbscan_mask = df['Cluster_DBSCAN'] != -1
if dbscan_mask.sum() > 0:
    score_dbscan = silhouette_score(X_scaled[dbscan_mask], df['Cluster_DBSCAN'][dbscan_mask])
    print("DBSCAN Silhouette Score:", score_dbscan)
else:
    print("DBSCAN found no clusters (all points noise), silhouette score cannot be computed")
# Out:
# DBSCAN Silhouette Score: -0.16154827690870635

# %%
X_pca_3d = pca_3d.fit_transform(X_scaled)

fig = plt.figure(figsize=(18, 6))

ax2 = fig.add_subplot(projection='3d')
scatter2 = ax2.scatter(X_pca_3d[:, 0], X_pca_3d[:, 1], X_pca_3d[:, 2], c=df['Cluster_DBSCAN'], cmap='tab10', s=10)
ax2.set_title('DBSCAN Clusters')
ax2.set_xlabel('PCA1')
ax2.set_ylabel('PCA2')
ax2.set_zlabel('PCA3')
fig.colorbar(scatter2, ax=ax2, shrink=0.5)

# %%
# Get cluster counts
dbscan_counts = df['Cluster_DBSCAN'].value_counts().sort_index()

fig, axes = plt.subplots(figsize=(5, 5))

axes.bar(dbscan_counts.index.astype(str), dbscan_counts.values)
axes.set_title('DBSCAN Cluster Counts')
axes.set_xlabel('Cluster Label')
axes.set_ylabel('Number of Samples')

plt.show()

# %% [markdown]
# # Mulitivariate Outliers
#
# ## Local Outlier Factor Method (LOF)

# %%
from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor(n_neighbors=50, contamination='auto')
df['Cluster_LOF'] = clf.fit_predict(X_scaled)

# %%
X_pca_3d = pca_3d.fit_transform(X_scaled)

fig = plt.figure(figsize=(18, 6))

ax2 = fig.add_subplot(projection='3d')
scatter2 = ax2.scatter(X_pca_3d[:, 0], X_pca_3d[:, 1], X_pca_3d[:, 2], c=df['Cluster_LOF'], cmap='bwr', s=10)
ax2.set_title('LOF Clusters')
ax2.set_xlabel('PCA1')
ax2.set_ylabel('PCA2')
ax2.set_zlabel('PCA3')
fig.colorbar(scatter2, ax=ax2, shrink=0.5)
